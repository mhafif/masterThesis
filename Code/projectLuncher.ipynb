# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !rm -rf "/content/celeba48"
# !rm -rf "/content/celeba48.zip"
# !cp "/content/drive/My Drive/Thesis/Data/celeba48.zip" "/content"
# !mkdir "/content/celeba48"
# !unzip -q "/content/celeba48.zip" -d "/content/celeba48"
# !rm -rf "/content/celeba48.zip"

# %%
#!zip -r "run.zip" "/content/drive/My Drive/Thesis/Sources/GAN/run"

# %% [markdown]
# function ClickConnect(){
# console.log("Working");
# document.querySelector("colab-toolbar-button#connect").click()
# }
# setInterval(ClickConnect,60000)

# %%
# !python3 "/content/drive/My Drive/Thesis/Sources/GAN/GAN.py"
# Out:
# Using TensorFlow backend.
# 2020-07-13 22:59:12.863667: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# tcmalloc: large alloc 1415577600 bytes == 0x6a932000 @  0x7f5ec90f21e7 0x7f5ec6c185e1 0x7f5ec6c7cc78 0x7f5ec6c7fdb8 0x7f5ec6c80395 0x7f5ec6d1765d 0x50a635 0x50bfb4 0x509758 0x50a48d 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7f5ec8cefb97 0x5b250a
# tcmalloc: large alloc 1415577600 bytes == 0xbef32000 @  0x7f5ec90f21e7 0x7f5ec6c185e1 0x7f5ec6c7f420 0x7f5ec6d0cf87 0x50a635 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7f5ec8cefb97 0x5b250a
# tcmalloc: large alloc 1415577600 bytes == 0x6a932000 @  0x7f5ec90f21e7 0x7f5ec6c185e1 0x7f5ec6c7cc78 0x7f5ec6c7cd93 0x7f5ec6e75037 0x7f5ec6e77492 0x7f5ec6e7830e 0x5a47fc 0x5a4ec8 0x7f5ec6d3b54b 0x59c940 0x50cb79 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7f5ec8cefb97 0x5b250a
# ...
